# %%
import pandas as pd 
# library for data manipulation
import matplotlib.pyplot as plt # library for visualization
import seaborn as sns # library for visualization
sns.set() # this command sets the seaborn chart style as the default

from matplotlib.ticker import PercentFormatter #converts values into percentage format

# %%
#load the real estate data for the scatter plot
df_real_estate = pd.read_csv("scatter_data.csv")

# %%
df_real_estate.head(10)
#display large number of points using Scatter plots!
# Out:
#      ID  Building Type  Year of sale  Month of sale Type of property  \
# 0  1030              1        2005.0           11.0        Apartment
# 1  1029              1        2005.0           10.0        Apartment
# 2  2002              2        2007.0            7.0        Apartment
# 3  2031              2        2007.0           12.0        Apartment
# 4  1049              1        2004.0           11.0        Apartment
# 5  3011              3        2007.0            9.0        Apartment
# 6  3026              3        2007.0            9.0        Apartment
# 7  3023              3        2008.0            1.0        Apartment
# 8  1031              1        2006.0            6.0        Apartment
# 9  4023              4        2006.0            3.0        Apartment
#
#    Property #  Area (ft.)      Price  Status
# 0          30      743.09  246.17268   Sold
# 1          29      756.21  246.33190   Sold
# 2           2      587.28  209.28091   Sold
# ...

# %%
plt.figure(figsize = (12, 8)) # size of the figure
scatter = plt.scatter(df_real_estate['Area (ft.)'],
            df_real_estate['Price'])
plt.show() ## initial scatter plot
#when you have many elements this causes overplotting
#add transparency level (sounds so nerdy but thats the term)

# %%
plt.figure(figsize = (12, 8)) # size of the figure
scatter = plt.scatter(df_real_estate['Area (ft.)'],
            df_real_estate['Price'], alpha = 0.6, #transparency level of points on the plot. Used to avoid overplotting
            c = df_real_estate['Building Type']) #another color to make it look better
plt.show()

# %%
plt.figure(figsize = (12, 8)) # size of the figure
scatter = plt.scatter(df_real_estate['Area (ft.)'],
            df_real_estate['Price'], 
            alpha = 0.6, #transparency level of points on the plot. Used to avoid overplotting
            c = df_real_estate['Building Type'], # additional third feature
            cmap = 'inferno') #auto color for you USE GOOGLE TO FIND MORE
plt.legend(*scatter.legend_elements(), # take legend_elements() using your scatter variable and set
           #automatically your Legends as Building Type 1 2 3 4 5
           loc = "upper left",
           title = "Building Type")
plt.show()

# %%
listcolors=['black', 'darkblue', 'crimson', 'pink', 'green']
# the seaborn scatter plot is used very often, as it is usually very intuitive to handle.
# This is also a main advantage of the library, the fact that it is easy to use. Though in some cases,
plt.figure(figsize = (12, 8))
sns.scatterplot(df_real_estate['Area (ft.)'], #refer seaborn using sns.scatterplot()
                df_real_estate['Price'],
                hue = df_real_estate['Building Type'], #third variable is added with the hue parameter
                #third variable (building type) hue is your third parameter for the third color!!!!
                palette = listcolors, #colors for the third parameter
                s = 100) # size of points on the scatter
plt.title("Relationship between Area and Price of California Real Estate", 
          fontsize = 14,   #change the font size
          weight = "bold")
plt.xlabel("Area (sq. ft.)", weight = "bold") #NOTHing complicated add x and ylabel
plt.ylabel("Price (000's of bitcoin)",fontsize=20)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [7], line 5
#       2 # the seaborn scatter plot is used very often, as it is usually very intuitive to handle.
#       3 # This is also a main advantage of the library, the fact that it is easy to use. Though in some cases,
#       4 plt.figure(figsize = (12, 8))
# ----> 5 sns.scatterplot(df_real_estate['Area (ft.)'], #refer seaborn using sns.scatterplot()
#       6                 df_real_estate['Price'],
#       7                 hue = df_real_estate['Building Type'], #third variable is added with the hue parameter
#       8                 #third variable (building type) hue is your third parameter for the third color!!!!
#       9                 palette = listcolors, #colors for the third parameter
#      10                 s = 100) # size of points on the scatter
# ...

# %% [raw]
# Your HW is to plot the GPA and SAT student scores using a scatter plot.
# USE: student_scores_data.csv
# Decide which will be your x- and y-axis
# Think about chart interpretation.
# Consider altering the chart limits, so the y-axis doesn’t start from 0.

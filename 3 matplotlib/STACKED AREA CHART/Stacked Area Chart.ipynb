# %%
import pandas as pd # library for data manipulation
import matplotlib.pyplot as plt # library for visualization
import seaborn as sns # library for visualization
sns.set() # this command sets the seaborn chart style as the default

# %%
# load data.
df_fuel_engine_types = pd.read_csv("stacked_area_chart_data.csv")
#this graphs are good when you have some timeline with multiple parameters to compare!
#its good for discovering patterns in your data!
#visualizations such as barchart might not be enough!

# %%
df_fuel_engine_types.head()
# Out:
#    Year   Gas  Petrol  Diesel  Other
# 0  1982     0      94       0      0
# 1  1983     0     347       0      0
# 2  1984   300       0     334      0
# 3  1985  1030    1184     984      0
# 4  1986   511     681    1066    340

# %%
plt.stackplot(df_fuel_engine_types["Year"],
              df_fuel_engine_types["Diesel"],
              df_fuel_engine_types["Petrol"],
              df_fuel_engine_types["Gas"])
plt.show()
#easy BUT NOT ENOUGH

# %%
plt.stackplot(df_fuel_engine_types["Year"],
              df_fuel_engine_types["Diesel"],
              df_fuel_engine_types["Petrol"],
              df_fuel_engine_types["Gas"])
plt.xticks(df_fuel_engine_types["Year"], rotation = 45)
plt.show()
#questionable but better

# %%
#select colors by HEX decimal coding
colors = ["#011638", "#7e2987", "ef2026"] #use google to check color codes by yourself dont ask everything
plt.stackplot(df_fuel_engine_types["Year"],
              df_fuel_engine_types["Diesel"],
              df_fuel_engine_types["Petrol"],
              df_fuel_engine_types["Gas"],
             colors=colors)
plt.xticks(df_fuel_engine_types["Year"], rotation = 45)
plt.show()

# %%
#maybe you are crazy about your graphs so you want to remove BORDER COLOR (WHITE HERE)

colors = ["#011638", "#7e2987", "ef2026"] #use good to check color codes byyourself dont ask everything
plt.stackplot(df_fuel_engine_types["Year"],
              df_fuel_engine_types["Diesel"],
              df_fuel_engine_types["Petrol"],
              df_fuel_engine_types["Gas"],
             colors=colors,edgecolor = 'none'
             )
plt.xticks(df_fuel_engine_types["Year"], rotation = 45)
plt.show()

# %%
#lets make it bigger because it was chaotic and small
labels = ["Diesel", "Petrol", "Gas"] #create a list!
colors = ["#011638", "#7e2987", "ef2026"]
plt.figure(figsize = (12, 6))
plt.stackplot(df_fuel_engine_types["Year"],
              df_fuel_engine_types["Diesel"],
              df_fuel_engine_types["Petrol"],
              df_fuel_engine_types["Gas"],
             colors=colors,edgecolor = 'none'
             )
plt.legend(labels = labels, loc = "upper left")  #use your list here for putting legend on upper left
plt.xticks(df_fuel_engine_types["Year"], rotation = 45)
plt.show()

# %%
# ADD A TITLE
import numpy as np
#array_rng = np.arange(start = 1990, stop =  2015, step = 10)
labels = ["Diesel", "Petrol", "Gas"] 
colors = ["#011638", "#7e2987", "ef2026"]
plt.figure(figsize = (12, 6))
plt.stackplot(df_fuel_engine_types["Year"],
              df_fuel_engine_types["Diesel"],
              df_fuel_engine_types["Petrol"],
              df_fuel_engine_types["Gas"],
             colors=colors,edgecolor = 'none'
             )
plt.legend(labels = labels, loc = "upper left")  
plt.xticks(df_fuel_engine_types["Year"], rotation = 45)
plt.title("Popularity of Engine Fuel Types (1982 - 2016)", fontsize = 14, weight = "bold")
plt.show()

# %%
# Create a stacked area chart, with pyplots 'stackplot'. On the x-axis we have the time line - year 1982 to 2016.
# On the y-axis we have the three categories, 'Diesel', 'Petrol' and 'Gas' stacked on top of each other. 
# Note that this ordering is chosen specifically so that categories are from largest to smallest.
# This helps us compare the size of the catogories, as people have difficulties determining the size of non-rectangular shapes.
# FULL COMMENTS HERE IF YOU WANNA 
# Provide a color list, so that each category can have a specific color.
# Color names should appear in the same order as the stacked area plot categories appear.  
colors = ["#011638", "#7e2987", "ef2026"]
# label list for the legend. Names should appear in the same order as the stacked area plot categories appear. 
labels = ["Diesel", "Petrol", "Gas"]
sns.set_style("white") # Use seaborn's 'white' theme to introduce a white background, instead of the default grey.
plt.figure(figsize = (12, 6))
plt.stackplot(df_fuel_engine_types["Year"],
              df_fuel_engine_types["Diesel"],
              df_fuel_engine_types["Petrol"],
              df_fuel_engine_types["Gas"],
              colors = ["#011638", "#7e2987", "ef2026"],
              edgecolor = 'none')
plt.xticks(df_fuel_engine_types["Year"], rotation = 45) # Include x-axis labels for each year and rotate labels by 45 degrees.
plt.legend(labels = labels, loc = "upper right") # Add a legend and specify its location on the chart.
plt.ylabel("Number of Cars", fontsize = 13)
plt.title("Popularity of Engine Fuel Types (1982 - 2016)", fontsize = 14, weight = "bold")
sns.despine() # Remove top and right border of the chart. #SEABORN STYLE !!!!!!!
plt.show()

# %%
#STEP BY STEP YOU learn how to use stacked area charts
# follow the steps in my codes to add every detail for your visualization!
#seaborn provides advanced way of visualization 
#its like John Wick movies amongst other Action movies, can be also Matrix movies 
# use this visuzalization when you have Time data
# or you want to compare the volume Among Categories!
# when you have at least 3 or more categories or features!
# too many categories are not good for STacked Area chart!
#line charts can be better when you have too many categories
#you have to start from 0 
#this means x and y axis should start from ZERO!!!
# if you want to mislead your colleagues you can start from something else :D

# %% [raw]
# HOMEWORK!
# is to create a stacked area chart of a printer company and its revenue for the last 12 months. The data set contains monthly values in the span of a year and features three revenue sources:
# USE: `area_chart_homework_data.csv`
# International Printer Sales
# Domestic Printer Sales
# Services (fixed fee)
# Think about the ordering of the categories, as well as the appropriate colors when displaying your chart. After you’ve completed the chart think about interpretation. What does the chart show? Which would you say is the most important revenue source for the business and why? How does the performance of the company look when considering the Date factor?
